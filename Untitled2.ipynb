# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# %cd yolov5
# %pip install -qr requirements.txt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 13595, done.
# remote: Counting objects: 100% (119/119), done.
# remote: Compressing objects: 100% (51/51), done.
# remote: Total 13595 (delta 83), reused 91 (delta 68), pack-reused 13476
# Receiving objects: 100% (13595/13595), 12.15 MiB | 32.40 MiB/s, done.
# Resolving deltas: 100% (9483/9483), done.
# /content/yolov5
#      |████████████████████████████████| 596 kB 5.2 MB/s

# %%
import torch
from IPython.display import Image,clear_output

clear_output()
print(torch.__version__)
print(torch.cuda.get_device_properties(0).name)
# Out:
# 1.11.0+cu113
# Tesla P100-PCIE-16GB

# %%
print(torch.__version__) # => 1.6.0a0+76c964d
print(torch.version.cuda) # => 10.2
print(torch.backends.cudnn.version()) # => 7605
# Out:
# 1.11.0+cu113
# 11.3
# 8200

# %%
# !nvidia-smi
# Out:
# Thu May 19 12:16:23 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   41C    P0    28W / 250W |      2MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !unzip -q /content/drive/MyDrive/data_animal.zip -d ../ #veri seti

# %%
# %pip install -q wandb
import wandb
wandb.login() #canlı grafikleri gösteriyor
# Out:
#      |████████████████████████████████| 1.8 MB 5.2 MB/s
#      |████████████████████████████████| 181 kB 63.7 MB/s
#      |████████████████████████████████| 145 kB 68.4 MB/s
#      |████████████████████████████████| 63 kB 1.6 MB/s
# ...
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
# !python train.py --img 640 --batch 16 --epochs 75 --data custom.yaml --weights yolov5x.pt --cache #
# Out:
# wandb: Currently logged in as: abdullahkrkrz. Use `wandb login --relogin` to force relogin
# train: weights=yolov5x.pt, cfg=, data=custom.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=5, batch_size=20, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=300, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.1-203-gfe1b503 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# ...
